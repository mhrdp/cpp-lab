# %%
# %%writefile test.cpp
#
# # include <iostream>
# int main()
# {
#     int i{2};
#
#     std::cout << i << std::endl;
# }
# Out:
# Overwriting test.cpp

# %%
# %%shell
#
# g++ test.cpp -o output1
# ./output1
# Out:
# 2
